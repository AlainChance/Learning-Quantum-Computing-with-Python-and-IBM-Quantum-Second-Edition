# %% [markdown]
# ## Chapter 6 - Understanding Quantum Logic Gates
# This Jupyter notebook has been updated to work with Python 3.12 and the following Qiskit versions:
# * Qiskit v1.3, Qiskit runtime version: 0.34
# * Qiskit v 2.0, Qiskit runtime version: 0.37
# |||
# |-|-|
# |**Author:** |Robert Loredo|
# |**Reviewer:** |Alain Chancé|
# |**Date:** |April 12, 2025|
# |**Version:** |**1.00**<br/>*Details see at the end of this notebook*|
# |**References:**|
# [Robert Loredo, Learn Quantum Computing with Python and IBM Quantum: Write your own practical quantum programs with Python, Second Edition, Packt, Feb 25, 2025](https://www.packtpub.com/en-us/product/learn-quantum-computing-with-python-and-ibm-quantum-9781803240923)
# [Learning-Quantum-Computing-with-Python-and-IBM-Quantum-Second-Edition/Chapter 6 - Understanding Multi-qubit gates (1).ipynb](https://github.com/PacktPublishing/Learning-Quantum-Computing-with-Python-and-IBM-Quantum-Second-Edition/blob/main/Chapter%206%20-%20Understanding%20Multi-qubit%20gates%20(1).ipynb)
# [Packt's code repository for the book](https://github.com/PacktPublishing/Learning-Quantum-Computing-with-Python-and-IBM-Quantum-Second-Edition)
# [LICENSE](https://github.com/PacktPublishing/Learning-Quantum-Computing-with-Python-and-IBM-Quantum-Second-Edition/blob/main/LICENSE)
# <br/>

# %%
# Load helper file
# %run helper_file_1.0.ipynb
# Out:
# Token read from file:  Token.txt
# Qiskit version: 2.0.0
# Qiskit runtime version: 0.37.0
# /home/alain/miniconda3/bin/python
# Python 3.12.9

# %% [markdown]
# # Single qubit gates

# %% [markdown]
# ## Hadamard ($H$) gate

# %%
# Hadamard gate
#H-gate
#Create the single qubit circuit
qc = QuantumCircuit(1)
#Add an H gate to the qubit
qc.h(0)
#Execute the circuit and capture all the results
result, img, qsphere, bloch_sphere = execute_circuit_sv(qc)
# Added by Alain Chancé
display(array_to_latex(result, prefix="\\text{state vector results} = ", precision = 4))
result.draw('latex')
# Out:
# $$
# \text{state vector results} =
# \begin{bmatrix}
# 0.7071 & 0.7071  \\
#  \end{bmatrix}
# $$
# $$\frac{\sqrt{2}}{2} |0\rangle+\frac{\sqrt{2}}{2} |1\rangle$$

# %%
result
# Out:
# Statevector([0.70710678+0.j, 0.70710678+0.j],
#             dims=(2,))

# %%
img

# %% [markdown]
# Figure 6.4: Circuit diagram with an $H$ gate

# %%
bloch_sphere

# %% [markdown]
# Figure 6.5: $H$ gate Bloch sphere

# %%
qsphere

# %% [markdown]
# Figure 6.6: $H$ gate QSphere representation

# %% [markdown]
# ## Pauli X gate

# %%
#Pauli gate
#X-gate
#Create the single qubit circuit
qc = QuantumCircuit(1)
#Add an X gate to the qubit
qc.x(0)
#Execute the circuit and capture all the results
result, img, qsphere, bloch_sphere = execute_circuit_sv(qc)
# Added by Alain Chancé
display(array_to_latex(result, prefix="\\text{state vector results} = ", precision = 1))
result.draw('latex')
# Out:
# $$
# \text{state vector results} =
# \begin{bmatrix}
# 0 & 1  \\
#  \end{bmatrix}
# $$
# $$ |1\rangle$$

# %%
result
# Out:
# Statevector([0.+0.j, 1.+0.j],
#             dims=(2,))

# %%
img

# %% [markdown]
# Figure 6.7: $X$ gate

# %%
bloch_sphere

# %% [markdown]
# Figure 6.8: $X$ gate Bloch sphere

# %%
qsphere

# %% [markdown]
# Figure 6.9: $X$ gate QSphere

# %% [markdown]
# ## Pauli $Y$ gate

# %%
# Pauli Y gate
#Y-gate operation on a qubit
#Create the single qubit circuit
qc = QuantumCircuit(1)
#Add a Y gate to the qubit
qc.y(0)
#Execute the circuit and capture all the results returned
result, img, qsphere, bloch_sphere = execute_circuit_sv(qc)
# Added by Alain Chancé
display(array_to_latex(result, prefix="\\text{state vector results} = ", precision = 1))
result.draw('latex')
# Out:
# $$
# \text{state vector results} =
# \begin{bmatrix}
# 0 & i  \\
#  \end{bmatrix}
# $$
# $$i |1\rangle$$

# %%
result
# Out:
# Statevector([0.+0.j, 0.+1.j],
#             dims=(2,))

# %%
img

# %% [markdown]
# Figure 6.10: $Y$ gate

# %%
bloch_sphere

# %% [markdown]
# Figure 6.11: $Y$ gate Bloch sphere

# %%
qsphere

# %% [markdown]
# Figure 6.12: $Y$ gate QSphere

# %% [markdown]
# ## Pauli $Z$ gate

# %%
# Pauli Z gate
#Z-gate
#Create the single qubit circuit
qc = QuantumCircuit(1)
#Add an H gate to the qubit to set the qubit in #superposition
qc.h(0)
#Add a Z gate to the qubit to rotate out of phase by π/2
qc.z(0)
#Execute the circuit and capture all the results
result, img, qsphere, bloch_sphere = execute_circuit_sv(qc)
# Added by Alain Chancé
display(array_to_latex(result, prefix="\\text{state vector results} = ", precision = 4))
result.draw('latex')
# Out:
# $$
# \text{state vector results} =
# \begin{bmatrix}
# 0.7071 & -0.7071  \\
#  \end{bmatrix}
# $$
# $$\frac{\sqrt{2}}{2} |0\rangle- \frac{\sqrt{2}}{2} |1\rangle$$

# %%
result
# Out:
# Statevector([ 0.70710678+0.j, -0.70710678+0.j],
#             dims=(2,))

# %%
img

# %% [markdown]
# Figure 6.13: Circuit diagram with a $Z$ gate

# %%
bloch_sphere

# %% [markdown]
# Figure 6.14: $Z$ gate Bloch sphere

# %%
qsphere

# %% [markdown]
# Figure 6.15: $Z$ gate QSphere representation after first applying an $H$ gate

# %% [markdown]
# ## $S$ gate

# %%
#S-gate
#Create the single qubit circuit
qc = QuantumCircuit(1)
#Add an H gate to the qubit to drop the vector onto the #X-axis
qc.h(0)
#Add an S gate to the qubit
qc.s(0)
#Execute the circuit and capture all the results
result, img, qsphere, bloch_sphere = execute_circuit_sv(qc)
# Added by Alain Chancé
display(array_to_latex(result, prefix="\\text{state vector results} = ", precision = 4))
result.draw('latex')
# Out:
# $$
# \text{state vector results} =
# \begin{bmatrix}
# 0.7071 & 0.7071 i  \\
#  \end{bmatrix}
# $$
# $$\frac{\sqrt{2}}{2} |0\rangle+\frac{\sqrt{2} i}{2} |1\rangle$$

# %%
result
# Out:
# Statevector([0.70710678+0.j        , 0.        +0.70710678j],
#             dims=(2,))

# %%
img

# %% [markdown]
# Figure 6.16: Circuit with an $S$ gate

# %%
bloch_sphere

# %% [markdown]
# Figure 6.17: $S$ gate Bloch sphere

# %%
qsphere

# %% [markdown]
# Figure 6.18: $S$ gate, $\pi/2$ phase rotation on the QSphere

# %% [markdown]
# ## $S^\dagger$ (dagger) gate

# %%
#Sdg-gate
#Create the single qubit circuit
qc = QuantumCircuit(1)
#Add an H gate to the qubit to drop the vector onto the #X-axis
qc.h(0)
#Add an S† gate to the qubit
qc.sdg(0)
#Execute the circuit and capture all the results
result, img, qsphere, bloch_sphere = execute_circuit_sv(qc)
# Added by Alain Chancé
display(array_to_latex(result, prefix="\\text{state vector results} = ", precision = 4))
result.draw('latex')
# Out:
# $$
# \text{state vector results} =
# \begin{bmatrix}
# 0.7071 & - 0.7071 i  \\
#  \end{bmatrix}
# $$
# $$\frac{\sqrt{2}}{2} |0\rangle- \frac{\sqrt{2} i}{2} |1\rangle$$

# %%
result
# Out:
# Statevector([0.70710678+0.j        , 0.        -0.70710678j],
#             dims=(2,))

# %%
img

# %% [markdown]
# Figure 6.19: Circuit with an $S^\dagger$ gate

# %%
bloch_sphere

# %% [markdown]
# Figure 6.20: $S^\dagger$ gate Bloch sphere

# %%
qsphere

# %% [markdown]
# Figure 6.21: $S^\dagger$ gate, $-\pi/2$ phase rotation on the QSphere

# %% [markdown]
# ## $T$ gate

# %%
#T-gate
#Create the single qubit circuit
qc = QuantumCircuit(1)
#Add an H gate to the qubit to drop the vector onto the #X-axis
qc.h(0)
#Add a T gate to the qubit
qc.t(0)
#Execute the circuit and capture all the results
result, img, qsphere, bloch_sphere = execute_circuit_sv(qc)
# Added by Alain Chancé
display(array_to_latex(result, prefix="\\text{state vector results} = ", precision = 4))
result.draw('latex')
# Out:
# $$
# \text{state vector results} =
# \begin{bmatrix}
# 0.7071 & \frac{1}{2} + \frac{i}{2}  \\
#  \end{bmatrix}
# $$
# $$\frac{\sqrt{2}}{2} |0\rangle+(\frac{1}{2} + \frac{i}{2}) |1\rangle$$

# %%
result
# Out:
# Statevector([0.70710678+0.j , 0.5       +0.5j],
#             dims=(2,))

# %%
img

# %% [markdown]
# Figure 6.22: Circuit representation of the T gate

# %%
bloch_sphere

# %% [markdown]
# Figure 6.23: $T$ gate Bloch sphere

# %%
qsphere

# %% [markdown]
# Figure 6.24: $T$ gate, $\pi/4$ phase rotation on the QSphere

# %% [markdown]
# ## $T^\dagger$ (dagger) gate

# %%
#Tdg-gate
#Create the single qubit circuit
qc = QuantumCircuit(1)
#Add an H gate to the qubit to drop the vector onto the #X-axis
qc.h(0)
#Add a Tdg gate to the qubit
qc.tdg(0)
#Execute the circuit and capture all the results
result, img, qsphere, bloch_sphere = execute_circuit_sv(qc)
# Added by Alain Chancé
display(array_to_latex(result, prefix="\\text{state vector results} = ", precision = 4))
result.draw('latex')
# Out:
# $$
# \text{state vector results} =
# \begin{bmatrix}
# 0.7071 & \frac{1}{2} - \frac{i}{2}  \\
#  \end{bmatrix}
# $$
# $$\frac{\sqrt{2}}{2} |0\rangle+(\frac{1}{2} - \frac{i}{2}) |1\rangle$$

# %%
result
# Out:
# Statevector([0.70710678+0.j , 0.5       -0.5j],
#             dims=(2,))

# %%
img

# %% [markdown]
# Figure 6.25: Circuit representation using $T^\dagger$ gate

# %%
bloch_sphere

# %% [markdown]
# Figure 6.26: $T^\dagger$ gate, $-\pi/4$ phase rotation on the Bloch sphere

# %%
qsphere

# %% [markdown]
# Figure 6.27: $T^\dagger$ gate, $-\pi/4$ phase rotation on the QSphere

# %% [markdown]
# ## $RZ$ gate

# %%
#Rz-gate
#Create the single qubit circuit
qc = QuantumCircuit(1)
#Import pi from the math library
from math import pi
#Add an H gate to help visualize phase rotation
qc.h(0)
#Add an RZ gate with an arbitrary angle theta of pi/6
qc.rz(pi/6, 0)
#Execute the circuit and capture all the results
result, img, qsphere, bloch_sphere = execute_circuit_sv(qc)
# Added by Alain Chancé
display(array_to_latex(result, prefix="\\text{state vector results} = ", precision = 4))
result.draw('latex')
# Out:
# $$
# \text{state vector results} =
# \begin{bmatrix}
# 0.683 - 0.183 i & 0.683 + 0.183 i  \\
#  \end{bmatrix}
# $$
# $$(0.6830127019 - 0.1830127019 i) |0\rangle+(0.6830127019 + 0.1830127019 i) |1\rangle$$

# %%
result
# Out:
# Statevector([0.6830127-0.1830127j, 0.6830127+0.1830127j],
#             dims=(2,))

# %%
img

# %% [markdown]
# Figure 6.28: Circuit representation using $RZ$ gate

# %%
bloch_sphere

# %% [markdown]
# Figure 6.29: $RZ$ gate Bloch sphere

# %%
qsphere

# %% [markdown]
# Figure 6.30: $RZ$ gate QSphere transitioned phase of $\pi/6$

# %%
#U-gate
from math import pi
#Create a single qubit circuit
qc = QuantumCircuit(1)
#Add a U gate and rotate all parameters by pi/2, and #apply it to the qubit
qc.u(pi/2, pi/2, pi/2, 0)
#Execute the circuit and capture all the results
result, img, qsphere, bloch_sphere = execute_circuit_sv(qc)
# Added by Alain Chancé
display(array_to_latex(result, prefix="\\text{state vector results} = ", precision = 4))
result.draw('latex')
# Out:
# $$
# \text{state vector results} =
# \begin{bmatrix}
# 0.7071 & 0.7071 i  \\
#  \end{bmatrix}
# $$
# $$\frac{\sqrt{2}}{2} |0\rangle+\frac{\sqrt{2} i}{2} |1\rangle$$

# %%
result
# Out:
# Statevector([7.07106781e-01+0.j        , 4.32978028e-17+0.70710678j],
#             dims=(2,))

# %%
img

# %% [markdown]
# Figure 6.31: The $U$ gate set with all rotation parameters to $\pi/2$

# %%
bloch_sphere

# %% [markdown]
# Figure 6.32: $U$ gate, Bloch sphere representation with all parameters set to $\pi/2$

# %%
qsphere

# %% [markdown]
# Figure 6.33: The QSphere representation of the $U$ gate set with all parameters to $\pi/2$

# %% [markdown]
# # Multi-qubit gates

# %% [markdown]
# ## $CNOT$ two-qubit gate

# %%
#CNOT-gate 
#Create a two qubit circuit
qc = QuantumCircuit(2)
#Add an H gate to the qubit
qc.h(0)
#Add an CNOT gate where, control = first, target = second qubit
qc.cx(0,1)
#Measure all qubits and send results to classical bits 
qc.measure_all()
#Execute the circuit and capture all the counts
counts, img, histogram = execute_circuit_returns(qc)

# %%
counts
# Out:
# {'11': 484, '00': 540}

# %%
img

# %% [markdown]
# Figure 6.34: Circuit representation using a $CNOT$ gate

# %%
histogram

# %% [markdown]
# Figure 6.35: Histogram representation of $CNOT$ results from circuit where the $Y$-axis represents the quasi-probabilities of the result.

# %% [markdown]
# ## Toffoli multi-qubit gate

# %%
#Toffoli (CCX)-gate
#Create a three qubit circuit
qc = QuantumCircuit(3)
#Enable the Controls qubits of the Toffoli gate
qc.x(range(2))
#Add the Toffoli gate (CCX)
qc.ccx(0,1,2)
#Execute the circuit and capture all the results
result, img, qsphere, bloch_sphere = execute_circuit_sv(qc)

# %%
print(result)
# Out:
# Statevector([0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j,
#              1.+0.j],
#             dims=(2, 2, 2))

# %%
bloch_sphere

# %% [markdown]
# Figure 6.36: Bloch sphere representation from the Toffoli (CCX) gate circuit results

# %%
qsphere

# %% [markdown]
# Figure 6.37: Qsphere representation from the Toffoli ($CCX$) gate circuit results

# %%
img

# %% [markdown]
# Figure 6.38: Circuit representation of a Toffoli ($CCX$) gate

# %%
qc_decomposed = qc.decompose()
qc_decomposed.draw(output="mpl")

# %% [markdown]
# Figure 6.39: Gates necessary to create a Toffoli ($CCX$) gate

# %% [markdown]
# ## Swap gate

# %%
#Swap-gate
from math import pi
#Create a two qubit circuit
qc = QuantumCircuit(2)
#Qubit 0 is initialized to |0> state
#Prepare qubit 1 to the |1> state
qc.x(1)
#Now swap gates
qc.swap(0,1)
#Execute the circuit and capture all the results
result, img, qsphere, bloch_sphere = execute_circuit_sv(qc)

# %%
result
# Out:
# Statevector([0.+0.j, 1.+0.j, 0.+0.j, 0.+0.j],
#             dims=(2, 2))

# %%
img

# %% [markdown]
# Figure 6.40: Circuit diagram of an $X$ gate followed by a Swap gate

# %%
bloch_sphere

# %% [markdown]
# Figure 6.41: Bloch sphere representation of a Swap gate

# %%
qsphere

# %% [markdown]
# Figure 6.42: QSphere representation after applying the Swap gate

# %% [markdown]
# # Measurement operator

# %%
#CNOT-gate
#Create a two qubit circuit
qc = QuantumCircuit(2)
#Add an H gate to the qubit
qc.h(0)
#Add an CNOT gate where, control = first, target = second #qubit
qc.cx(0,1)
#Measure qubits and map to classical bits
qc.measure_all()
#Execute the circuit and capture all the results
result, img, histogram = execute_circuit_returns(qc)

# %%
result
# Out:
# {'00': 501, '11': 523}

# %%
histogram

# %% [markdown]
# Figure 6.43: Histogram chart of measured results

# %%
img

# %% [markdown]
# Figure 6.44: Measurement operators added to a quantum circuit

# %%
#Measurement operator
#Create two separate two-qubit, and two-classical bit circuits
qc1 = QuantumCircuit(2,2)
qc2 = QuantumCircuit(2,2)

#In the first circuit (qc1), measure qubits individually 
qc1.measure(0,0)
qc1.measure(1,1)

#In the second circuit (qc2) measure using a list
# Modified by Alain chancé
#qc2.measure([0,1],[0,1])
qc2.measure_all()

#Execute the circuit and capture all the results
#result, img, histogram = execute_circuit_returns(qc1)
#result2, img2, histogram2 = execute_circuit_returns(qc2)

# %%
qc1.draw(output='mpl')

# %%
qc2.draw(output='mpl')

# %%
#img

# %%
#img2

# %%
#import qiskit_ibm_runtime
#qiskit_ibm_runtime.version.get_version_info

# %%
#import qiskit

#qiskit.version.get_version_info

# %% [markdown]
# ## Print Qiskit version

# %%
import qiskit
print(f"Qiskit version: {qiskit.__version__}")
# Out:
# Qiskit version: 2.0.0

# %% [markdown]
# ## Print Qiskit runtime version

# %%
import qiskit_ibm_runtime
print(f"Qiskit runtime version: {qiskit_ibm_runtime.__version__}")
# Out:
# Qiskit runtime version: 0.37.0

# %% [markdown]
# ## Show Python version

# %%
# %%bash
# which python
# python --version
# Out:
# /home/alain/miniconda3/bin/python
# Python 3.12.9
